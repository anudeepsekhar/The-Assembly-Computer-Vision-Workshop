# %% [markdown]
# # Working with images in OpenCV

# %% [markdown]
# ### Importing neccessary libraries

# %%
# %pylab notebook
import numpy as np
import matplotlib.pyplot as plt
import cv2
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Reading and displaying images with Numpy/Matplotlib

# %%
image = imread('data/cat.jpg')

# %%
imshow(image)
# Out:
# <img src="data:image/png;base64,..." width="639.6">

# %% [markdown]
# ### Now doing it the OpenCV way..!

# %%
image_cv = cv2.imread('data/cat.jpg')

# %%
imshow(image_cv)

# %%
cv2.imshow('image', image_cv)
cv2.waitKey()
cv2.destroyWindow('image')

# %% [markdown]
# ### Writing images to file

# %%
cv2.imwrite('data/write_cat.jpg',image_cv)
# Out:
# True

# %%
# %ls data
# Out:
#  Volume in drive C has no label.
#  Volume Serial Number is 2488-1A5C
#
#  Directory of C:\Users\dell\Documents\Projects\Assembly CV Workshop\The-Assembly-Computer-Vision-Worshop\Notebooks\data
#
# 11/25/2019  07:18 PM    <DIR>          .
# 11/25/2019  07:18 PM    <DIR>          ..
# 11/25/2019  02:09 PM             4,188 cat.jpg
# 11/25/2019  02:29 PM            41,791 messi.jpg
# 11/25/2019  05:10 PM            98,482 messigray.png
# 11/25/2019  03:02 PM               201 number.png
# 07/18/2019  02:56 PM           139,388 sample1.JPG
# 07/18/2019  03:14 PM           152,201 sample2.JPG
# 07/18/2019  02:57 PM           176,581 sample3.JPG
# 11/25/2019  07:49 PM             9,183 write_cat.jpg
#                8 File(s)        622,015 bytes
#                2 Dir(s)  155,515,695,104 bytes free

# %% [markdown]
# ### Exploring image properties

# %%
#Shape of the image
image_shape = image_cv.shape
print('image shape: ' + str(image_shape))
# Out:
# image shape: (260, 194, 3)

# %%
#Type of the image
image_type = image_cv.dtype
print('image type: ' + str(image_type))
# Out:
# image type: uint8

# %%
#Accessing individual pixel value of the image
pixel_value = image_cv[55][75]
print(pixel_value)
# Out:
# [148 171 193]

# %% [markdown]
# ### Putting it all together
#
# Note: Press 'E'

# %%
#Read image
img = cv2.imread('data/messi.jpg',0)

#Display image
cv2.imshow('image',img)

#Shape of the image
image_shape = img.shape
print('image shape: ' + str(image_shape))

#Type of the image
image_type = img.dtype
print('image type: ' + str(image_type))

#Accessing individual pixel value of the image
pixel_value = img[55][75]
print(pixel_value)


k = cv2.waitKey(0)
if k == 27:         # wait for ESC key to exit
    cv2.destroyAllWindows()
elif k == ord('s'): # wait for 's' key to save and exit
    cv2.imwrite('data/messigray.png',img)
    cv2.destroyAllWindows()
# Out:
# image shape: (420, 620)
# image type: uint8
# 14
